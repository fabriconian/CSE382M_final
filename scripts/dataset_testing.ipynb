# %%
import pandas as pd
from cleanvision.imagelab import Imagelab

# %%
imagelab = Imagelab(data_path="../inputs_resized/flowers")
# Out:
# Reading images from /Users/visyn/Documents/education/UT/4_semester/STAT_ML/final/inputs_resized/flowers

# %%
imagelab.find_issues()
# Out:
# Checking for dark, light, odd_aspect_ratio, low_information, exact_duplicates, near_duplicates, blurry, grayscale images ...
# ...
# 100%|███████████████████████████████████████████████████████████████████████████████| 4317/4317 [00:03<00:00, 1095.81it/s]
# Issue checks completed. To see a detailed report of issues found, use imagelab.report().

# %%
imagelab.report()
# Out:
# Issues found in order of severity in the dataset
#
# |    | issue_type       |   num_images |
# |---:|:-----------------|-------------:|
# |  0 | blurry           |           79 |
# |  1 | near_duplicates  |           16 |
# |  2 | exact_duplicates |           12 |
# |  3 | low_information  |            1 |
#
#
# Top 4 examples with blurry issue in the dataset.
# Top 4 sets of images with near_duplicates issue
# Set: 0
# Set: 1
# Set: 2
# Set: 3
# Top 4 sets of images with exact_duplicates issue
# Set: 0
# Set: 1
# Set: 2
# Set: 3
# Found 1 example with low_information issue in the dataset.

# %%
imagelab.issue_summary
# Out:
#          issue_type num_images
# 0            blurry         30
# 1   near_duplicates         14
# 2  exact_duplicates         12
# 3  odd_aspect_ratio          6
# 4   low_information          1
# 5              dark          0
# 6         grayscale          0
# 7             light          0
